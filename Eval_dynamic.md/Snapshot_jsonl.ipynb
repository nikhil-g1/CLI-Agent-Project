# %%
import json

with open("trace.jsonl") as f:
    all_logs = [json.loads(line) for line in f]

#Accessing each logged instruction
for entry in all_logs:
    print(entry.get("step", "No step found"))
    print("------")
# Out:
# Step-by-step plan for: Create a new Git branch and switch to it.
# ------
# What is the goal of the given task?
# ------
# Create a new Git branch and switch to it.
# ------
# What is the problem?
# ------
# What is the solution?
# ------
# What are the steps?
# ------
# What is the outcome?
# ------
# 1. Make a new branch: Create a new Git branch and make it the first step in the process.
# ------
# 2. Switch to the new branch: Switch to the newly created branch in the Git repository.
# ------
# 3. Commit the new branch: Commit the new branch to the Git repository.
# ------
# 4. Push the new branch to the main branch: Push the new branch to the main branch to add it as a branch in the repository.
# ------
# 5. Log the changes: Log the changes made to the branch in the Git repository.
# ------
# What are the steps?
# ------
# What is the outcome?
# ------
# ...

# %% [markdown]
# #Summary Table
#
# | Prompt # | Plan Quality |
# |----------|---------------|
# | 1        | 2             |
# | 2        | 2             |
# | 3        | 2             |
# | 4        | 2             |
# | 5        | 0             |
# | 6        | 2             |
# | 7        | 2             |
